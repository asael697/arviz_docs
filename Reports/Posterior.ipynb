# %% [raw]
# ---
# title: "Evaluation of the plot_posterior effectiveness"
# author: "Asael Alonzo M"
# format:
#   html:
#     toc: true
#     code-copy: true
#     code-fold: true
#     self-contained: true
#     smooth-scroll: true
#     anchor-sections: true
# jupyter: python3
# ---

# %% [markdown]
# ## Posterior density plot: Kruschke’s style
#
# The `plot_posterior` function from `ArviZ` helps visualize the posterior distribution using a kernel density estimation method (KDE). This function is the ArviZ equivalent of `mcmc_hist()` and `mcmc_dens()` functions from the [bayesplot](https://mc-stan.org/bayesplot/reference/MCMC-intervals.html) package. The functionality and defaults are similar for the three functions, but `ArviZ` plot,s by default. present the distribution truncated at their $100\times(1-\alpha)\%$ highest density intervals.
#
# @fig-posterior shows the default density plots for $\theta$ in the eight schools example.

# %%
#| label: fig-post
#| fig-cap: "Posterior densities for theta, 8 schools example"

import arviz as az
import matplotlib.pyplot as plt

centered = az.load_arviz_data('centered_eight')
az.style.use("arviz-darkgrid")

az.plot_posterior(centered)

plt.show()

# %% [markdown]
# ## Analysis of current defaults
#
#  + These plot should be the default option for the `plot_density` function as they have the same utility, but different aesthetics.
#
# ## Analysis of usage advise
#
#   + Update the **function**'s description. Generate KDE plots for continuous variables and histograms for discrete ones.
#
#       - "Plot Posterior densities in the style of John K. Kruschke’s book. The Credible intervals are truncated at their 100*(1-alpha)% highest density. The function generates KDE plots for continuous variables and histograms for discrete ones."
#
#   + The `skipna` option defaults to `False`. Is there a reason why?
#
# ## Relevant Issues
#
#  + Issue: [#2090](https://github.com/arviz-devs/arviz/issues/2080): Reorganize layout in Posterior Plot
